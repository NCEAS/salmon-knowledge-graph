# %% [markdown]
# ## Install & Import Statements
# Import: See the inline comments for a brief rational of each library.
#
# Notes: The SPARQLWrapper libary provides tools for querying SPARQL endpoints. The sparql_dataframe library can be used with SPARQLWrapper to convert JSON results from a SPARQL query directly to a Pandas dataframe. The mapclassify library is required by GeoPandas for its .explore functionality.

# %%
from branca.element import Figure                                  # For controlling the size of the final map
import folium                                                      # For map layer control
import geopandas as gpd                                            # For geospatial dataframes
import pandas as pd                                                # For dataframes
from shapely import wkt                                            # For working with WKT coordinates in a GeoDataFrame
from SPARQLWrapper import SPARQLWrapper, JSON, GET, POST, DIGEST   # For querying SPARQL endpoints
import sparql_dataframe                                            # For converting SPARQL query results to Pandas dataframes
from rdflib import Graph
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from itertools import cycle

# %% [markdown]
# ## Variable Initialization
# A SPARQLWrapper is created to access the SAWGraph repository for the SAWGraph project.

# %%
# %%capture
pd.options.display.width = 240
endpointPOST = 'http://Shirlys-MacBook-Pro.local:7200/repositories/streamnet'
sparqlPOST = SPARQLWrapper(endpointPOST)

# %% [markdown]
# ## Queries
#
# These queries directly access data in Salmon Knowledge Graph that houses the GBIF, Streamnet results. They use federation to access additional data in KWG repositories.
#
#
# The query is executed and returned as a dataframe.

# %%
query1="""
PREFIX time: <http://www.w3.org/2006/time#>
PREFIX fish-ont: <http://purl.dataone.org/fish-ont/>
PREFIX prov-o: <https://www.w3.org/TR/prov-o/>
PREFIX geo: <http://www.opengis.net/ont/geosparql#>
PREFIX sosa: <http://www.w3.org/ns/sosa/>
PREFIX streamnet-ont: <https://knb.ecoinformatics.org/knb/streamnet/lod/ontology/>
PREFIX nosa-ont: <https://knb.ecoinformatics.org/knb/streamnet/nosa/lod/ontology/>
PREFIX nosar: <https://knb.ecoinformatics.org/knb/streamnet/nosa/lod/resource/>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>

SELECT ?recovery_domain ?water_body ?wkt ?sampled_date
WHERE {
    # ?nosa_obs_coll a nosa-ont:Escapement_ObservationCollection;
    		fish-ont:hasTemporalContext ?sampled_date;
    		sosa:hasFeatureOfInterest ?location.
    # ?location geo:hasGeometry ?geo;
    		fish-ont:locatedIn ?water_body_iri;
    		fish-ont:associatedRegion ?recovery_domain_iri.
	# ?geo geo:hasGeometry|geo:asWKT ?wkt.
    # ?water_body_iri rdfs:label ?water_body.
    # ?recovery_domain_iri rdfs:label ?recovery_domain.
}
"""
sparqlPOST.setQuery(query1)
sparqlPOST.setReturnFormat(JSON)

try:
    # results = sparqlPOST.query().convert()
    # for result in results["results"]["bindings"]:
    #     print(result)
    nosa_df1 = sparql_dataframe.get(endpointPOST, query1)
    # print(df)
except Exception as e:
    print(f"An error occurred: {e}")

# %%
query2="""
PREFIX time: <http://www.w3.org/2006/time#>
PREFIX fish-ont: <http://purl.dataone.org/fish-ont/>
PREFIX prov-o: <https://www.w3.org/TR/prov-o/>
PREFIX geo: <http://www.opengis.net/ont/geosparql#>
PREFIX sosa: <http://www.w3.org/ns/sosa/>
PREFIX streamnet-ont: <https://knb.ecoinformatics.org/knb/streamnet/lod/ontology/>
PREFIX nosa-ont: <https://knb.ecoinformatics.org/knb/streamnet/nosa/lod/ontology/>
PREFIX nosar: <https://knb.ecoinformatics.org/knb/streamnet/nosa/lod/resource/>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>

SELECT ?recovery_domain ?water_body ?wkt ?salmon_species ?nosaij
WHERE {
    # ?nosa_obs_coll a nosa-ont:Escapement_ObservationCollection;
    		fish-ont:hasTemporalContext ?time;
    		sosa:hasFeatureOfInterest ?location;
    		fish-ont:ofSpeciesType ?salmon_species;
    		sosa:hasMember ?nosa_obs.
    # ?nosa_obs sosa:observedProperty nosa-ont:salmonCharacteristic.NOSAIJ;
            sosa:hasSimpleResult ?nosaij.
    # ?location geo:hasGeometry ?geo;
    		fish-ont:locatedIn ?water_body_iri;
    		fish-ont:associatedRegion ?recovery_domain_iri.
	# ?geo geo:hasGeometry|geo:asWKT ?wkt.
    # ?water_body_iri rdfs:label ?water_body.
    # ?recovery_domain_iri rdfs:label ?recovery_domain.
    FILTER (?time = "2018"^^xsd:gYear)
}
"""
sparqlPOST.setQuery(query2)
sparqlPOST.setReturnFormat(JSON)

try:
    # results = sparqlPOST.query().convert()
    # for result in results["results"]["bindings"]:
    #     print(result)
    nosa_df2 = sparql_dataframe.get(endpointPOST, query2)
    # print(df)
except Exception as e:
    print(f"An error occurred: {e}")


query3="""
PREFIX time: <http://www.w3.org/2006/time#>
PREFIX fish-ont: <http://purl.dataone.org/fish-ont/>
PREFIX prov-o: <https://www.w3.org/TR/prov-o/>
PREFIX geo: <http://www.opengis.net/ont/geosparql#>
PREFIX sosa: <http://www.w3.org/ns/sosa/>
PREFIX streamnet-ont: <https://knb.ecoinformatics.org/knb/streamnet/lod/ontology/>
PREFIX nosa-ont: <https://knb.ecoinformatics.org/knb/streamnet/nosa/lod/ontology/>
PREFIX nosar: <https://knb.ecoinformatics.org/knb/streamnet/nosa/lod/resource/>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>

SELECT ?recovery_domain ?water_body ?wkt ?salmon_species ?nosaij
WHERE {
    # ?nosa_obs_coll a nosa-ont:Escapement_ObservationCollection;
    		fish-ont:hasTemporalContext ?time;
    		sosa:hasFeatureOfInterest ?location;
    		fish-ont:ofSpeciesType ?salmon_species;
    		sosa:hasMember ?nosa_obs.
    # ?nosa_obs sosa:observedProperty nosa-ont:salmonCharacteristic.NOSAIJ;
            sosa:hasSimpleResult ?nosaij.
    # ?location geo:hasGeometry ?geo;
    		fish-ont:locatedIn ?water_body_iri;
    		fish-ont:associatedRegion ?recovery_domain_iri.
	# ?geo geo:hasGeometry|geo:asWKT ?wkt.
    # ?water_body_iri rdfs:label ?water_body.
    # ?recovery_domain_iri rdfs:label ?recovery_domain.
    FILTER (?time = "2019"^^xsd:gYear)
}
"""
sparqlPOST.setQuery(query3)
sparqlPOST.setReturnFormat(JSON)

try:
    # results = sparqlPOST.query().convert()
    # for result in results["results"]["bindings"]:
    #     print(result)
    nosa_df3 = sparql_dataframe.get(endpointPOST, query3)
    # print(df)
except Exception as e:
    print(f"An error occurred: {e}")

query4="""
PREFIX time: <http://www.w3.org/2006/time#>
PREFIX fish-ont: <http://purl.dataone.org/fish-ont/>
PREFIX prov-o: <https://www.w3.org/TR/prov-o/>
PREFIX geo: <http://www.opengis.net/ont/geosparql#>
PREFIX sosa: <http://www.w3.org/ns/sosa/>
PREFIX streamnet-ont: <https://knb.ecoinformatics.org/knb/streamnet/lod/ontology/>
PREFIX nosa-ont: <https://knb.ecoinformatics.org/knb/streamnet/nosa/lod/ontology/>
PREFIX nosar: <https://knb.ecoinformatics.org/knb/streamnet/nosa/lod/resource/>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>

SELECT ?recovery_domain ?water_body ?wkt ?salmon_species ?nosaij
WHERE {
    # ?nosa_obs_coll a nosa-ont:Escapement_ObservationCollection;
    		fish-ont:hasTemporalContext ?time;
    		sosa:hasFeatureOfInterest ?location;
    		fish-ont:ofSpeciesType ?salmon_species;
    		sosa:hasMember ?nosa_obs.
    # ?nosa_obs sosa:observedProperty nosa-ont:salmonCharacteristic.NOSAIJ;
            sosa:hasSimpleResult ?nosaij.
    # ?location geo:hasGeometry ?geo;
    		fish-ont:locatedIn ?water_body_iri;
    		fish-ont:associatedRegion ?recovery_domain_iri.
	# ?geo geo:hasGeometry|geo:asWKT ?wkt.
    # ?water_body_iri rdfs:label ?water_body.
    # ?recovery_domain_iri rdfs:label ?recovery_domain.
    FILTER (?time = "2020"^^xsd:gYear)
}
"""
sparqlPOST.setQuery(query4)
sparqlPOST.setReturnFormat(JSON)

try:
    # results = sparqlPOST.query().convert()
    # for result in results["results"]["bindings"]:
    #     print(result)
    nosa_df4 = sparql_dataframe.get(endpointPOST, query4)
    # print(df)
except Exception as e:
    print(f"An error occurred: {e}")

query5="""
PREFIX time: <http://www.w3.org/2006/time#>
PREFIX fish-ont: <http://purl.dataone.org/fish-ont/>
PREFIX prov-o: <https://www.w3.org/TR/prov-o/>
PREFIX geo: <http://www.opengis.net/ont/geosparql#>
PREFIX sosa: <http://www.w3.org/ns/sosa/>
PREFIX streamnet-ont: <https://knb.ecoinformatics.org/knb/streamnet/lod/ontology/>
PREFIX nosa-ont: <https://knb.ecoinformatics.org/knb/streamnet/nosa/lod/ontology/>
PREFIX nosar: <https://knb.ecoinformatics.org/knb/streamnet/nosa/lod/resource/>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>

SELECT ?recovery_domain ?water_body ?wkt ?salmon_species ?nosaij
WHERE {
    # ?nosa_obs_coll a nosa-ont:Escapement_ObservationCollection;
    		fish-ont:hasTemporalContext ?time;
    		sosa:hasFeatureOfInterest ?location;
    		fish-ont:ofSpeciesType ?salmon_species;
    		sosa:hasMember ?nosa_obs.
    # ?nosa_obs sosa:observedProperty nosa-ont:salmonCharacteristic.NOSAIJ;
            sosa:hasSimpleResult ?nosaij.
    # ?location geo:hasGeometry ?geo;
    		fish-ont:locatedIn ?water_body_iri;
    		fish-ont:associatedRegion ?recovery_domain_iri.
	# ?geo geo:hasGeometry|geo:asWKT ?wkt.
    # ?water_body_iri rdfs:label ?water_body.
    # ?recovery_domain_iri rdfs:label ?recovery_domain.
    FILTER (?time = "2021"^^xsd:gYear)
}
"""
sparqlPOST.setQuery(query3)
sparqlPOST.setReturnFormat(JSON)

try:
    # results = sparqlPOST.query().convert()
    # for result in results["results"]["bindings"]:
    #     print(result)
    nosa_df5 = sparql_dataframe.get(endpointPOST, query5)
    # print(df)
except Exception as e:
    print(f"An error occurred: {e}")

# %% [markdown]
# ## Visualizing on a map

# %% [markdown]
# **bold text** Create GeoPandas dataframes for mapping
#
# Convert the above dataframes to GeoDataFrames, setting the WKT columns as the geometry columns and setting the CRS to WGS 84.

# %%
nosa_df1['wkt'] = nosa_df1['wkt'].apply(wkt.loads)
nosa_df1= nosa_df1[['recovery_domain', 'water_body', 'wkt', 'sampled_date']]

nosa_df2['wkt'] = nosa_df2['wkt'].apply(wkt.loads)
nosa_df2= nosa_df2[['recovery_domain', 'water_body', 'wkt', 'salmon_species', 'nosaij']]

nosa_df3['wkt'] = nosa_df3['wkt'].apply(wkt.loads)
nosa_df3= nosa_df3[['recovery_domain', 'water_body', 'wkt', 'salmon_species', 'nosaij']]

nosa_df4['wkt'] = nosa_df4['wkt'].apply(wkt.loads)
nosa_df4= nosa_df4[['recovery_domain', 'water_body', 'wkt', 'salmon_species', 'nosaij']]

nosa_df5['wkt'] = nosa_df5['wkt'].apply(wkt.loads)
nosa_df5= nosa_df5[['recovery_domain', 'water_body', 'wkt', 'salmon_species', 'nosaij']]

# %%
# %%capture
nosa_df1 = gpd.GeoDataFrame(nosa_df1, geometry='wkt')
nosa_df1.set_crs(epsg=4326, inplace=True, allow_override=True)

nosa_df2 = gpd.GeoDataFrame(nosa_df2, geometry='wkt')
nosa_df2.set_crs(epsg=4326, inplace=True, allow_override=True)

nosa_df3 = gpd.GeoDataFrame(nosa_df3, geometry='wkt')
nosa_df3.set_crs(epsg=4326, inplace=True, allow_override=True)

nosa_df4 = gpd.GeoDataFrame(nosa_df4, geometry='wkt')
nosa_df4.set_crs(epsg=4326, inplace=True, allow_override=True)

nosa_df5 = gpd.GeoDataFrame(nosa_df5, geometry='wkt')
nosa_df5.set_crs(epsg=4326, inplace=True, allow_override=True)

# %% [markdown]
# # Visualizing on a map

# %%
from folium.plugins import MarkerCluster
from folium import CircleMarker

# %%
#%%capture
fac_color = 'black'
boundweight = 5

map = nosa_df1.explore(
        style_kwds=dict(weight=boundweight, style_function=lambda x: {"color": "Green"}), 
                     tooltip=True,
                     name='NOSA Escapement Locations',
                     show=True)
# m = folium.Map(location=[gbif_abundance_gdf.geometry.centroid.y.mean(), 
#                          gbif_abundance_gdf.geometry.centroid.x.mean()], 
#                zoom_start=10)

# for _, row in gbif_abundance_gdf.iterrows():
#     lat, lon = row.wkt.y, row.wkt.x
#     folium.CircleMarker(
#         location=[lat, lon],
#         radius=5,  # Size of the circle
#         color="blue",  # Circle border color
#         fill=True,
#         fill_color="cyan",  # Fill color
#         fill_opacity=0.6,
#         popup=f"Value: {row['value']}, Year: {row['year']}",
#         tooltip=row['obs_point'],
#     ).add_to(m)

# %% [markdown]
# ## Show map
#
# The map is created inside a Figure box to control its size. This displays the samples sized by the max measured concentration of any PFAs chemical

# %%
# map.save('Salmon observation points in Bresle River)

fig = Figure(width=1200, height=800)
fig.add_child(map)

# m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ddd29ae950daff755580beeec77d49a0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ddd29ae950daff755580beeec77d49a0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ddd29ae950daff755580beeec77d49a0 = L.map(
#                 &quot;map_ddd29ae950daff755580beeec77d49a0&quot;,
#                 {
#                     center: [46.11685, -120.36105],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;maxBounds&quot;: null,
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_ddd29ae950daff755580beeec77d49a0);
#
#
#
#
#
#             var tile_layer_01ef307a7cc218b2b385fd7260979cdc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_01ef307a7cc218b2b385fd7260979cdc.addTo(map_ddd29ae950daff755580beeec77d49a0);
#
#
#             map_ddd29ae950daff755580beeec77d49a0.fitBounds(
#                 [[43.2839, -123.7173], [48.9498, -117.0048]],
#                 {}
#             );
#
#
#         function geo_json_80ec76a8bd20376bd19407e7f0a6f16c_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;Green&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 5};
#             }
#         }
#         function geo_json_80ec76a8bd20376bd19407e7f0a6f16c_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_80ec76a8bd20376bd19407e7f0a6f16c_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_80ec76a8bd20376bd19407e7f0a6f16c_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_80ec76a8bd20376bd19407e7f0a6f16c_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_80ec76a8bd20376bd19407e7f0a6f16c.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_80ec76a8bd20376bd19407e7f0a6f16c_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_80ec76a8bd20376bd19407e7f0a6f16c = L.geoJson(null, {
#                 onEachFeature: geo_json_80ec76a8bd20376bd19407e7f0a6f16c_onEachFeature,
#
#                 style: geo_json_80ec76a8bd20376bd19407e7f0a6f16c_styler,
#                 pointToLayer: geo_json_80ec76a8bd20376bd19407e7f0a6f16c_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_80ec76a8bd20376bd19407e7f0a6f16c_add (data) {
#             geo_json_80ec76a8bd20376bd19407e7f0a6f16c
#                 .addData(data);
#         }
#             geo_json_80ec76a8bd20376bd19407e7f0a6f16c_add({&quot;bbox&quot;: [-123.7173, 43.2839, -117.0048, 48.9498], &quot;features&quot;: [{&quot;bbox&quot;: [-121.5235, 45.665, -121.5235, 45.665], &quot;geometry&quot;: {&quot;coordinates&quot;: [-121.5235, 45.665], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;recovery_domain&quot;: &quot;Willamette/Lower Columbia&quot;, &quot;sampled_date&quot;: 2007, &quot;water_body&quot;: &quot;Hood River&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-123.5806, 46.1459, -123.5806, 46.1459], &quot;geometry&quot;: {&quot;coordinates&quot;: [-123.5806, 46.1459], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;recovery_domain&quot;: &quot;Willamette/Lower Columbia&quot;, &quot;sampled_date&quot;: 2015, &quot;water_body&quot;: &quot;Big Creek&quot;}, &quot;type&quot;:

# %% [markdown]
# ## Create map with multiple layers
#
# Each GeoDataFrame is a layer in the final map.

# %%
from folium import LayerControl
fac_color = 'black'
boundweight = 5

map = nosa_df2.explore(
        style_kwds=dict(weight=boundweight, style_function=lambda x: {"color": "Green"}),
                     tooltip=True,
                     name='NOSA Escapement Locations - 2019',
                     show=True)
nosa_df3.explore(m=map,
                  color='blue',
                  style_kwds=dict(weight=boundweight),
                  tooltip=True,
                  name='NOSA Escapement Locations - 2020',
                  show=True)
nosa_df4.explore(m=map,
                color='Orange',
                style_kwds=dict(weight=boundweight),
                tooltip=True,
                name='NOSA Escapement Locations - 2021',
                show=True)
nosa_df4.explore(m=map,
                color='DeepPink',
                style_kwds=dict(weight=boundweight),
                tooltip=True,
                name='NOSA Escapement Locations - 2022',
                show=True)
# m = folium.Map(location=[gbif_abundance_gdf.geometry.centroid.y.mean(), 
#                          gbif_abundance_gdf.geometry.centroid.x.mean()], 
#                zoom_start=10)

# for _, row in gbif_abundance_gdf.iterrows():
#     lat, lon = row.wkt.y, row.wkt.x
#     folium.CircleMarker(
#         location=[lat, lon],
#         radius=5,  # Size of the circle
#         color="blue",  # Circle border color
#         fill=True,
#         fill_color="cyan",  # Fill color
#         fill_opacity=0.6,
#         popup=f"Value: {row['value']}, Year: {row['year']}",
#         tooltip=row['obs_point'],
#     ).add_to(m)
LayerControl().add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a979431572952034b894541f4e5144a0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a979431572952034b894541f4e5144a0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a979431572952034b894541f4e5144a0 = L.map(
#                 &quot;map_a979431572952034b894541f4e5144a0&quot;,
#                 {
#                     center: [47.260450000000006, -120.2927],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;maxBounds&quot;: null,
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_a979431572952034b894541f4e5144a0);
#
#
#
#
#
#             var tile_layer_2fd5f6386cdfa2d388e24767cb2ac3a5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2fd5f6386cdfa2d388e24767cb2ac3a5.addTo(map_a979431572952034b894541f4e5144a0);
#
#
#             map_a979431572952034b894541f4e5144a0.fitBounds(
#                 [[45.5711, -123.5806], [48.9498, -117.0048]],
#                 {}
#             );
#
#
#         function geo_json_59d3321b8ff42a5fa908a5f9f6e985b3_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;Green&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 5};
#             }
#         }
#         function geo_json_59d3321b8ff42a5fa908a5f9f6e985b3_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_59d3321b8ff42a5fa908a5f9f6e985b3_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_59d3321b8ff42a5fa908a5f9f6e985b3_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_59d3321b8ff42a5fa908a5f9f6e985b3_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_59d3321b8ff42a5fa908a5f9f6e985b3.resetStyle(e.target);
#                     }
#                 },

# %% [markdown]
# ## Retrieve Controlled Vocabulary
#
# Get terms or classification schemes across all Streamnet datasets. These terms form a common integrating layer over all datasets, i.e., NOSA, RperS, JuvOut,

# %% [markdown]
# Retrieve all Salmon species sampled/observed in various Streamnet datasets

# %%
query_species ="""
PREFIX : <http://ecoinformatics.org/oboe/oboe.1.2/oboe.owl#>
PREFIX oboe-core: <http://ecoinformatics.org/oboe/oboe.1.2/oboe-core.owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX time: <http://www.w3.org/2006/time#>
PREFIX fish-ont: <http://purl.dataone.org/fish-ont/>
PREFIX prov-o: <https://www.w3.org/TR/prov-o/>
PREFIX geo: <http://www.opengis.net/ont/geosparql#>
PREFIX sosa: <http://www.w3.org/ns/sosa/>
PREFIX streamnet-ont: <https://knb.ecoinformatics.org/knb/streamnet/lod/ontology/>
PREFIX nosa-ont: <https://knb.ecoinformatics.org/knb/streamnet/nosa/lod/ontology/>
PREFIX nosar: <https://knb.ecoinformatics.org/knb/streamnet/nosa/lod/resource/>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX juvout-ont: <https://knb.ecoinformatics.org/knb/streamnet/JUVOUT/lod/ontology/>
PREFIX sar-ont: <https://knb.ecoinformatics.org/knb/streamnet/SAR/lod/ontology/>
PREFIX rpers-ont: <https://knb.ecoinformatics.org/knb/streamnet/rpers/lod/ontology/>
SELECT DISTINCT ?dataset_iri ?dataset_name ?salmon_species_iri ?salmon_species_name
WHERE {
    # ?obs_coll a ?o;
    	fish-ont:ofSpeciesType ?salmon_species_iri;
    	prov-o:wasDerivedFrom ?dataset_iri.
    # ?dataset_iri oboe-core:title ?dataset_name.
    # ?salmon_species_iri rdfs:label ?salmon_species_name.
    FILTER (?o = juvout-ont:Escapement_ObservationCollection || ?o = nosa-ont:Escapement_ObservationCollection || ?o = sar-ont:Escapement_ObservationCollection || ?o = rpers-ont:Escapement_ObservationCollection)
}

"""
sparqlPOST.setQuery(query_species)
sparqlPOST.setReturnFormat(JSON)

try:
    # results = sparqlPOST.query().convert()
    # for result in results["results"]["bindings"]:
    #     print(result)
    species_df = sparql_dataframe.get(endpointPOST, query_species)
    print(species_df)
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
#                                           dataset_iri                             dataset_name                           salmon_species_iri salmon_species_name
# 0   http://ecoinformatics.org/oboe/oboe.1.2/oboe-c...            Juvenile Outmigrants (JuvOut)  http://purl.dataone.org/odo/SALMON_00000570     Steelhead trout
# 1   http://ecoinformatics.org/oboe/oboe.1.2/oboe-c...            Juvenile Outmigrants (JuvOut)  http://purl.dataone.org/odo/SALMON_00000513      Chinook salmon
# 2   http://ecoinformatics.org/oboe/oboe.1.2/oboe-c...            Juvenile Outmigrants (JuvOut)  http://purl.dataone.org/odo/SALMON_00000514         Chum salmon
# 3   http://ecoinformatics.org/oboe/oboe.1.2/oboe-c...            Juvenile Outmigrants (JuvOut)  http://purl.dataone.org/odo/SALMON_00000517      Sockeye salmon
# 4   http://ecoinformatics.org/oboe/oboe.1.2/oboe-c...            Juvenile Outmigrants (JuvOut)  http://purl.dataone.org/odo/SALMON_00000515         Coho salmon
# 5   http://ecoinformatics.org/oboe/oboe.1.2/oboe-c...  Natural Origin Spawner Abundance (NOSA)  http://purl.dataone.org/odo/SALMON_00000570     Steelhead trout
# 6   http://ecoinformatics.org/oboe/oboe.1.2/oboe-c...  Natural Origin Spawner Abundance (NOSA)  http://purl.dataone.org/odo/SALMON_00000515         Coho salmon
# 7   http://ecoinformatics.org/oboe/oboe.1.2/oboe-c...  Natural Origin Spawner Abundance (NOSA)  http://purl.dataone.org/odo/SALMON_00000513      Chinook salmon
# 8   http://ecoinformatics.org/oboe/oboe.1.2/oboe-c...  Natural Origin Spawner Abundance (NOSA)  http://purl.dataone.org/odo/SALMON_00000517      Sockeye salmon
# 9   http://ecoinformatics.org/oboe/oboe.1.2/oboe-c...  Natural Origin Spawner Abundance (NOSA)  http://purl.dataone.org/odo/SALMON_00000514         Chum salmon
# 10  http://ecoinformatics.org/oboe/oboe.1.2/oboe-c...         Smolt to adult return rate (SAR)  http://purl.dataone.org/odo/SALMON_00000570     Steelhead trout
# 11  http://ecoinformatics.org/oboe/oboe.1.2/oboe-c...         Smolt to adult return rate (SAR)  http://purl.dataone.org/odo/SALMON_00000515         Coho salmon
# 12  http://ecoinformatics.org/oboe/oboe.1.2/oboe-c...         Smolt to adult return rate (SAR)  http://purl.dataone.org/odo/SALMON_00000513      Chinook salmon
# 13  http://ecoinformatics.org/oboe/oboe.1.2/oboe-c...         Smolt to adult return rate (SAR)  http://purl.dataone.org/odo/SALMON_00000517      Sockeye salmon
# 14  http://ecoinformatics.org/oboe/oboe.1.2/oboe-c...             Recruits per Spawner (RperS)  http://purl.dataone.org/odo/SALMON_00000515         Coho salmon
# 15  http://ecoinformatics.org/oboe/oboe.1.2/oboe-c...             Recruits per Spawner (RperS)  http://purl.dataone.org/odo/SALMON_00000513      Chinook salmon
# 16  http://ecoinformatics.org/oboe/oboe.1.2/oboe-c...             Recruits per Spawner (RperS)  http://purl.dataone.org/odo/SALMON_00000570     Steelhead trout
# 17  http://ecoinformatics.org/oboe/oboe.1.2/oboe-c...             Recruits per Spawner (RperS)  http://purl.dataone.org/odo/SALMON_00000517      Sockeye salmon
# 18  http://ecoinformatics.org/oboe/oboe.1.2/oboe-c...             Recruits per Spawner (RperS)  http://purl.dataone.org/odo/SALMON_00000514         Chum salmon

# %% [markdown]
# Retrieve all measured characteristics in various Streamnet datasets.

# %%
query_characteristic ="""
PREFIX : <http://ecoinformatics.org/oboe/oboe.1.2/oboe.owl#>
PREFIX oboe-core: <http://ecoinformatics.org/oboe/oboe.1.2/oboe-core.owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX time: <http://www.w3.org/2006/time#>
PREFIX fish-ont: <http://purl.dataone.org/fish-ont/>
PREFIX prov-o: <https://www.w3.org/TR/prov-o/>
PREFIX geo: <http://www.opengis.net/ont/geosparql#>
PREFIX sosa: <http://www.w3.org/ns/sosa/>
PREFIX streamnet-ont: <https://knb.ecoinformatics.org/knb/streamnet/lod/ontology/>
PREFIX nosa-ont: <https://knb.ecoinformatics.org/knb/streamnet/nosa/lod/ontology/>
PREFIX nosar: <https://knb.ecoinformatics.org/knb/streamnet/nosa/lod/resource/>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX juvout-ont: <https://knb.ecoinformatics.org/knb/streamnet/JUVOUT/lod/ontology/>
PREFIX sar-ont: <https://knb.ecoinformatics.org/knb/streamnet/SAR/lod/ontology/>
PREFIX rpers-ont: <https://knb.ecoinformatics.org/knb/streamnet/rpers/lod/ontology/>
SELECT DISTINCT ?dataset_name ?measured_characteristic_name ?measured_characteristic_description
WHERE {
    # ?obs_coll a ?o;
    	sosa:hasMember ?obs;
    	prov-o:wasDerivedFrom ?dataset_iri.
    # ?dataset_iri oboe-core:title ?dataset_name.
    # ?obs sosa:observedProperty ?measured_characteristic_iri.
    # ?measured_characteristic_iri rdfs:label ?measured_characteristic_name;
    	rdfs:comment ?measured_characteristic_description.
    FILTER (?o = juvout-ont:Escapement_ObservationCollection || ?o = nosa-ont:Escapement_ObservationCollection || ?o = sar-ont:Escapement_ObservationCollection || ?o = rpers-ont:Escapement_ObservationCollection)
}

"""
sparqlPOST.setQuery(query_characteristic)
sparqlPOST.setReturnFormat(JSON)

try:
    # results = sparqlPOST.query().convert()
    # for result in results["results"]["bindings"]:
    #     print(result)
    characteristic_df = sparql_dataframe.get(endpointPOST, query_characteristic)
    print(characteristic_df)
    characteristic_df.to_html("output_characteristic.html")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
#                                dataset_name measured_characteristic_name                measured_characteristic_description
# 0   Natural Origin Spawner Abundance (NOSA)                     Age3Prop  The proportion of natural origin fish that wer...
# 1   Natural Origin Spawner Abundance (NOSA)                     Age4Prop  The proportion of natural origin fish that wer...
# 2   Natural Origin Spawner Abundance (NOSA)                     Age5Prop  The proportion of natural origin fish that wer...
# 3   Natural Origin Spawner Abundance (NOSA)                     Age6Prop  The proportion of natural origin fish that wer...
# 4   Natural Origin Spawner Abundance (NOSA)                       NOSAIJ  Including jacks, point estimate for NOSA or na...
# 5   Natural Origin Spawner Abundance (NOSA)                       pHOSij  Point estimate for the proportion of fish spaw...
# 6   Natural Origin Spawner Abundance (NOSA)                        TSAIJ          Total spawner abundance, including jacks.
# 7   Natural Origin Spawner Abundance (NOSA)                     Age2Prop  The proportion of natural origin fish that wer...
# 8   Natural Origin Spawner Abundance (NOSA)                       NOSAEJ  Excluding jacks, point estimate for NOSA or na...
# 9   Natural Origin Spawner Abundance (NOSA)                       pHOSej  Point estimate for the proportion of fish spaw...
# 10  Natural Origin Spawner Abundance (NOSA)                        TSAEJ          Total spawner abundance, excluding jacks.
# 11  Natural Origin Spawner Abundance (NOSA)                        HOSJF            Hatchery origin spawners jack fraction.
# 12  Natural Origin Spawner Abundance (NOSA)                        NOSJF             Natural origin spawners jack fraction.
# 13             Recruits per Spawner (RperS)                   HarvestAdj  How the return was adjusted to account for har...
# 14             Recruits per Spawner (RperS)                     Recruits  Number of natural origin recruits from the ind...
# 15             Recruits per Spawner (RperS)              RecruitsMissing  Whether any recruits for this brood year were ...
# 16             Recruits per Spawner (RperS)                        RperS  Ratio of recruits from the designated brood ye...
# 17             Recruits per Spawner (RperS)                TotalSpawners  Total number of parent spawners, both natural ...
# 18             Recruits per Spawner (RperS)                  Age10Adults  Total number of adult recruits that were age 1...
# 19             Recruits per Spawner (RperS)                   Age2Adults  Total number of adult recruits that were age 2...
# 20             Recruits per Spawner (RperS)                   Age3Adults  Total number of adult recruits that were age 3...
# 21             Recruits per Spawner (RperS)                   Age4Adults  Total number of adult recruits that were age 4...
# 22             Recruits per Spawner (RperS)                   Age5Adults  Total number of adult recruits that were age 5...
# 23             Recruits per Spawner (RperS)                   Age6Adults  Total number of adult recruits that were age 6...
# 24             Recruits per Spawner (RperS)                   Age7Adults  Total number of adult recruits that were age 7...
# 25             Recruits per Spawner (RperS)                   Age8Adults  Total number of adult recruits that were age 8...
# 26             Recruits per Spawner (RperS)                   Age9Adults  Total number of adult recruits that were age 9...
# 27             Recruits per Spawner (RperS)             HatcherySpawners  Number of parent spawners of hatchery origin t...
# 28             Recruits per Spawner (RperS)          NOBroodStockRemoved  Additional recruits that would have returned h...
# 29             Recruits per Spawner (RperS)                 OceanHarvest  Number of adults and jacks from the recruit gr...
# 30             Recruits per Spawner (RperS)                  TribHarvest  Number of adults and jacks from the recruit gr...
# 31             Recruits per Spawner (RperS)                     Age1Juvs  Total number of juvenile recruits that were ag...
# 32             Recruits per Spawner (RperS)                     Age2Juvs  Total number of juvenile recruits at age 2 (br...
# 33             Recruits per Spawner (RperS)                     Age3Juvs  Total number of juvenile recruits at age 3 (br...
# 34             Recruits per Spawner (RperS)                 Age4PlusJuvs  Total number of juvenile recruits at age 4 (br...
# 35             Recruits per Spawner (RperS)                          YOY  Total number of juvenile recruits (parr or smo...

# %% [markdown]
# ## Cross-Graph Integration
# Establishing data connection across graphs (maintained by other groups/organizations)

# %%
from IPython.display import display
query_kwg="""
PREFIX kwg-ont: <http://stko-kwg.geog.ucsb.edu/lod/ontology/>
PREFIX : <http://ecoinformatics.org/oboe/oboe.1.2/oboe.owl#>
PREFIX oboe-core: <http://ecoinformatics.org/oboe/oboe.1.2/oboe-core.owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX time: <http://www.w3.org/2006/time#>
PREFIX fish-ont: <http://purl.dataone.org/fish-ont/>
PREFIX prov-o: <https://www.w3.org/TR/prov-o/>
PREFIX geo: <http://www.opengis.net/ont/geosparql#>
PREFIX sosa: <http://www.w3.org/ns/sosa/>
PREFIX streamnet-ont: <https://knb.ecoinformatics.org/knb/streamnet/lod/ontology/>
PREFIX nosa-ont: <https://knb.ecoinformatics.org/knb/streamnet/nosa/lod/ontology/>
PREFIX nosar: <https://knb.ecoinformatics.org/knb/streamnet/nosa/lod/resource/>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX juvout-ont: <https://knb.ecoinformatics.org/knb/streamnet/JUVOUT/lod/ontology/>
PREFIX sar-ont: <https://knb.ecoinformatics.org/knb/streamnet/SAR/lod/ontology/>
PREFIX rpers-ont: <https://knb.ecoinformatics.org/knb/streamnet/rpers/lod/ontology/>
SELECT ?location ?recovery_domain ?water_body ?region
WHERE {
    # ?nosa_obs_coll a nosa-ont:Escapement_ObservationCollection;
    		fish-ont:hasTemporalContext ?time;
    		sosa:hasFeatureOfInterest ?location;
    		sosa:hasMember ?nosa_obs.
    # ?nosa_obs sosa:observedProperty nosa-ont:salmonCharacteristic.NOSAIJ;
            sosa:hasSimpleResult ?nosaij.
    # ?location kwg-ont:sfWithin ?region.
    # ?location geo:hasGeometry ?geo;
    		fish-ont:locatedIn ?water_body_iri;
    		fish-ont:associatedRegion ?recovery_domain_iri.
#	?geo geo:hasGeometry|geo:asWKT ?wkt.
    # ?water_body_iri rdfs:label ?water_body.
    # ?recovery_domain_iri rdfs:label ?recovery_domain.
    FILTER (?time = "2018"^^xsd:gYear)
}

"""
sparqlPOST.setQuery(query_kwg)
sparqlPOST.setReturnFormat(JSON)

try:
    # results = sparqlPOST.query().convert()
    # for result in results["results"]["bindings"]:
    #     print(result)
    nosa_df10 = sparql_dataframe.get(endpointPOST, query_kwg)
    print(nosa_df10)
    nosa_df10.to_html("output_kwg-integrated.html")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
#                                              location            recovery_domain                                         water_body                                             region
# 0   https://knb.ecoinformatics.org/knb/streamnet/l...          Interior Columbia                                       Alpowa Creek  http://stko-kwg.geog.ucsb.edu/lod/resource/s2....
# 1   https://knb.ecoinformatics.org/knb/streamnet/l...          Interior Columbia                                       Alpowa Creek  http://stko-kwg.geog.ucsb.edu/lod/resource/adm...
# 2   https://knb.ecoinformatics.org/knb/streamnet/l...          Interior Columbia                                      Antoine Creek  http://stko-kwg.geog.ucsb.edu/lod/resource/s2....
# 3   https://knb.ecoinformatics.org/knb/streamnet/l...          Interior Columbia                                      Antoine Creek  http://stko-kwg.geog.ucsb.edu/lod/resource/adm...
# 4   https://knb.ecoinformatics.org/knb/streamnet/l...          Interior Columbia                                      Tenmile Creek  http://stko-kwg.geog.ucsb.edu/lod/resource/s2....
# 5   https://knb.ecoinformatics.org/knb/streamnet/l...          Interior Columbia                                      Tenmile Creek  http://stko-kwg.geog.ucsb.edu/lod/resource/adm...
# 6   https://knb.ecoinformatics.org/knb/streamnet/l...          Interior Columbia                                         Tunk Creek  http://stko-kwg.geog.ucsb.edu/lod/resource/s2....
# 7   https://knb.ecoinformatics.org/knb/streamnet/l...          Interior Columbia                                         Tunk Creek  http://stko-kwg.geog.ucsb.edu/lod/resource/adm...
# 8   https://knb.ecoinformatics.org/knb/streamnet/l...          Interior Columbia                                    Bonaparte Creek  http://stko-kwg.geog.ucsb.edu/lod/resource/s2....
# 9   https://knb.ecoinformatics.org/knb/streamnet/l...          Interior Columbia                                    Bonaparte Creek  http://stko-kwg.geog.ucsb.edu/lod/resource/adm...
# 10  https://knb.ecoinformatics.org/knb/streamnet/l...          Interior Columbia                                       George Creek  http://stko-kwg.geog.ucsb.edu/lod/resource/s2....
# 11  https://knb.ecoinformatics.org/knb/streamnet/l...          Interior Columbia                                       George Creek  http://stko-kwg.geog.ucsb.edu/lod/resource/adm...
# 12  https://knb.ecoinformatics.org/knb/streamnet/l...          Interior Columbia                                    Loup Loup Creek  http://stko-kwg.geog.ucsb.edu/lod/resource/s2....
# 13  https://knb.ecoinformatics.org/knb/streamnet/l...          Interior Columbia                                    Loup Loup Creek  http://stko-kwg.geog.ucsb.edu/lod/resource/adm...
# 14  https://knb.ecoinformatics.org/knb/streamnet/l...          Interior Columbia                                       Asotin Creek  http://stko-kwg.geog.ucsb.edu/lod/resource/s2....
# 15  https://knb.ecoinformatics.org/knb/streamnet/l...          Interior Columbia                                       Asotin Creek  http://stko-kwg.geog.ucsb.edu/lod/resource/adm...
# 16  https://knb.ecoinformatics.org/knb/streamnet/l...          Interior Columbia  Asotin Creek                                  ...  http://stko-kwg.geog.ucsb.edu/lod/resource/s2....
# 17  https://knb.ecoinformatics.org/knb/streamnet/l...          Interior Columbia  Asotin Creek                                  ...  http://stko-kwg.geog.ucsb.edu/lod/resource/adm...
# 18  https://knb.ecoinformatics.org/knb/streamnet/l...          Interior Columbia                                      Johnson Creek  http://stko-kwg.geog.ucsb.edu/lod/resource/s2....
# 19  https://knb.ecoinformatics.org/knb/streamnet/l...          Interior Columbia                                      Johnson Creek  http://stko-kwg.geog.ucsb.edu/lod/resource/adm...
# 20  https://knb.ecoinformatics.org/knb/streamnet/l...          Interior Columbia  Johnson Creek                                 ...  http://stko-kwg.geog.ucsb.edu/lod/resource/s2....
# 21  https://knb.ecoinformatics.org/knb/streamnet/l...          Interior Columbia  Johnson Creek                                 ...  http://stko-kwg.geog.ucsb.edu/lod/resource/adm...
# 22  https://knb.ecoinformatics.org/knb/streamnet/l...          Interior Columbia                                  Similkameen River  http://stko-kwg.geog.ucsb.edu/lod/resource/s2....
# 23  https://knb.ecoinformatics.org/knb/streamnet/l...          Interior Columbia                                  Similkameen River  http://stko-kwg.geog.ucsb.edu/lod/resource/adm...
# 24  https://knb.ecoinformatics.org/knb/streamnet/l...  Willamette/Lower Columbia  Hood River traps: WF Moving Falls (45.571/-121...  http://stko-kwg.geog.ucsb.edu/lod/resource/s2....
# 25  https://knb.ecoinformatics.org/knb/streamnet/l...  Willamette/Lower Columbia  Hood River traps: WF Moving Falls (45.571/-121...  http://stko-kwg.geog.ucsb.edu/lod/resource/adm...
# 26  https://knb.ecoinformatics.org/knb/streamnet/l...  Willamette/Lower Columbia                              East Fork Lewis River  http://stko-kwg.geog.ucsb.edu/lod/resource/s2....
# 27  https://knb.ecoinformatics.org/knb/streamnet/l...  Willamette/Lower Columbia                              East Fork Lewis River  http://stko-kwg.geog.ucsb.edu/lod/resource/adm...
# 28  https://knb.ecoinformatics.org/knb/streamnet/l...  Willamette/Lower Columbia                                          Big Creek  http://stko-kwg.geog.ucsb.edu/lod/resource/s2....
# 29  https://knb.ecoinformatics.org/knb/streamnet/l...  Willamette/Lower Columbia                                          Big Creek  http://stko-kwg.geog.ucsb.edu/lod/resource/adm...
# 30  https://knb.ecoinformatics.org/knb/streamnet/l...  Willamette/Lower Columbia  Big Creek                                     ...  http://stko-kwg.geog.ucsb.edu/lod/resource/s2....
# 31  https://knb.ecoinformatics.org/knb/streamnet/l...  Willamette/Lower Columbia  Big Creek                                     ...  http://stko-kwg.geog.ucsb.edu/lod/resource/adm...
# 32  https://knb.ecoinformatics.org/knb/streamnet/l...  Willamette/Lower Columbia                                    Washougal River  http://stko-kwg.geog.ucsb.edu/lod/resource/s2....
# 33  https://knb.ecoinformatics.org/knb/streamnet/l...  Willamette/Lower Columbia                                    Washougal River  http://stko-kwg.geog.ucsb.edu/lod/resource/adm...
# 34  https://knb.ecoinformatics.org/knb/streamnet/l...          Interior Columbia                                     Umatilla River  http://stko-kwg.geog.ucsb.edu/lod/resource/s2....
# 35  https://knb.ecoinformatics.org/knb/streamnet/l...          Interior Columbia                                     Umatilla River  http://stko-kwg.geog.ucsb.edu/lod/resource/adm...
# 36  https://knb.ecoinformatics.org/knb/streamnet/l...          Interior Columbia                                       Salmon Creek  http://stko-kwg.geog.ucsb.edu/lod/resource/s2....
# 37  https://knb.ecoinformatics.org/knb/streamnet/l...          Interior Columbia                                       Salmon Creek  http://stko-kwg.geog.ucsb.edu/lod/resource/adm...
# 38  https://knb.ecoinformatics.org/knb/streamnet/l...          Interior Columbia                                         Omak Creek  http://stko-kwg.geog.ucsb.edu/lod/resource/s2....
# 39  https://knb.ecoinformatics.org/knb/streamnet/l...          Interior Columbia                                         Omak Creek  http://stko-kwg.geog.ucsb.edu/lod/resource/adm...
# 40  https://knb.ecoinformatics.org/knb/streamnet/l...          Interior Columbia                                       Aeneas Creek  http://stko-kwg.geog.ucsb.edu/lod/resource/s2....
# 41  https://knb.ecoinformatics.org/knb/streamnet/l...          Interior Columbia                                       Aeneas Creek  http://stko-kwg.geog.ucsb.edu/lod/resource/adm...
# 42  https://knb.ecoinformatics.org/knb/streamnet/l...          Interior Columbia                                     Tucannon River  http://stko-kwg.geog.ucsb.edu/lod/resource/s2....
# 43  https://knb.ecoinformatics.org/knb/streamnet/l...          Interior Columbia                                     Tucannon River  http://stko-kwg.geog.ucsb.edu/lod/resource/adm...
# 44  https://knb.ecoinformatics.org/knb/streamnet/l...          Interior Columbia  Tucannon River                                ...  http://stko-kwg.geog.ucsb.edu/lod/resource/s2....
# 45  https://knb.ecoinformatics.org/knb/streamnet/l...          Interior Columbia  Tucannon River                                ...  http://stko-kwg.geog.ucsb.edu/lod/resource/adm...
